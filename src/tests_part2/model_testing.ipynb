# %% [markdown]
# # Testing suite for model bias comparison

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import onnxruntime as ort
from model_testing import (
    test_gender_bias,
    test_age_bias,
    test_history_of_development_bias,
    test_case_single_mother,
    test_case_immigrant_worker,
    test_case_high_risk_individual
)

# %% [markdown]
# ## Data mutation bias testing

# %%
# Define the model paths
model_1_path = "../../model/model_1.onnx"  # Path to Model 1
model_2_path = "../../model/model_2.onnx"  # Path to Model 2

# %% [markdown]
# ### Gender bias

# %%
# Run the Gender Bias Test
print("Running Gender Bias Test:")
p_val_gender = test_gender_bias(model_1_path, model_2_path)
# Out:
# Running Gender Bias Test:
# === Model 1 Results ===
# Accuracy for sample of 1000 Men: 51.1%
# Accuracy for sample of 1000 Women: 50.3%
# Percentage checked amongst Men: 59.4%
# Percentage checked changed to Women: 60.4%
# P value: 0.6484094076336846
#
# === Model 2 Results ===
# Accuracy for sample of 1000 Men: 89.1%
# Accuracy for sample of 1000 Women: 89.1%
# Percentage checked amongst Men: 0.0%
# Percentage checked changed to Women: 0.0%
# P value: nan

# %% [markdown]
# ### Age bias

# %%
# Run the Age Bias Test
print("Running Age Bias Test:")
p_val_age = test_age_bias(model_1_path, model_2_path)
# Out:
# Running Age Bias Test:
# === Model 1 Results ===
# Accuracy for sample of 500 20 Year Olds: 59.6%
# Accuracy for sample of 500 50 Year Olds: 68.8%
# Percentage checked amongst 20 Year Olds: 85.8%
# Percentage checked changed to 50 Year Olds: 76.6%
# P value: 0.00019042236245656665
#
# === Model 2 Results ===
# Accuracy for sample of 500 20 Year Olds: 54.0%
# Accuracy for sample of 500 50 Year Olds: 54.0%
# Percentage checked amongst 20 Year Olds: 0.2%
# Percentage checked changed to 50 Year Olds: 0.2%
# P value: 1.0

# %% [markdown]
# ### History of Development Bias

# %%
print("Running History of Development Bias Test:")
p_val_history = test_history_of_development_bias(model_1_path, model_2_path)
# Out:
# Running History of Development Bias Test:
# === Model 1 Results ===
# Accuracy for sample of 500 No Development Action Plan: 61.2%
# Accuracy for sample of 500 Has Development Action Plan: 73.0%
# Percentage checked amongst No Development Action Plan: 81.8%
# Percentage checked changed to Has Development Action Plan: 70.0%
# P value: 1.1984948082766536e-05
#
# === Model 2 Results ===
# Accuracy for sample of 500 No Development Action Plan: 57.0%
# Accuracy for sample of 500 Has Development Action Plan: 57.0%
# Percentage checked amongst No Development Action Plan: 0.0%
# Percentage checked changed to Has Development Action Plan: 0.0%
# P value: nan

# %% [markdown]
# ### Single mother bias

# %%
print("Running Single Mother Case Test:")
p_val_single_mother = test_case_single_mother(model_1_path, model_2_path)
# Out:
# Running Single Mother Case Test:
# === Model 1 Results ===
# Accuracy for sample of 500 Average male with no children: 48.0%
# Accuracy for sample of 500 Single mother with two children: 49.6%
# Percentage checked amongst Average male with no children: 61.2%
# Percentage checked changed to Single mother with two children: 59.2%
# P value: 0.5187324464816341
#
# === Model 2 Results ===
# Accuracy for sample of 500 Average male with no children: 90.4%
# Accuracy for sample of 500 Single mother with two children: 90.4%
# Percentage checked amongst Average male with no children: 0.0%
# Percentage checked changed to Single mother with two children: 0.0%
# P value: nan

# %% [markdown]
# ### Immigrant Worker bias

# %%
print("Running Immigrant Worker Case Test:")
p_val_immigrant_worker = test_case_immigrant_worker(model_1_path, model_2_path)
# Out:
# Running Immigrant Worker Case Test:
# === Model 1 Results ===
# Accuracy for sample of 500 Average Dutch male: 64.4%
# Accuracy for sample of 500 Immigrant worker with roommates: 62.0%
# Percentage checked amongst Average Dutch male: 46.2%
# Percentage checked changed to Immigrant worker with roommates: 48.6%
# P value: 0.4477724357554075
#
# === Model 2 Results ===
# Accuracy for sample of 500 Average Dutch male: 88.4%
# Accuracy for sample of 500 Immigrant worker with roommates: 88.4%
# Percentage checked amongst Average Dutch male: 0.2%
# Percentage checked changed to Immigrant worker with roommates: 0.2%
# P value: 1.0

# %% [markdown]
# ### High Risk Individual Bias

# %%
print("Running High Risk Individual Case Test:")
p_val_high_risk = test_case_high_risk_individual(model_1_path, model_2_path)
# Out:
# Running High Risk Individual Case Test:
# === Model 1 Results ===
# Accuracy for sample of 500 50 yr old men, know Dutch, no financial difficulties: 80.2%
# Accuracy for sample of 500 20 yr old mother of two, not Dutch-speaking, struggling financially: 59.4%
# Percentage checked amongst 50 yr old men, know Dutch, no financial difficulties: 20.8%
# Percentage checked changed to 20 yr old mother of two, not Dutch-speaking, struggling financially: 41.6%
# P value: 6.90105358915503e-13
#
# === Model 2 Results ===
# Accuracy for sample of 500 50 yr old men, know Dutch, no financial difficulties: 99.0%
# Accuracy for sample of 500 20 yr old mother of two, not Dutch-speaking, struggling financially: 99.0%
# Percentage checked amongst 50 yr old men, know Dutch, no financial difficulties: 0.0%
# Percentage checked changed to 20 yr old mother of two, not Dutch-speaking, struggling financially: 0.0%
# P value: nan
